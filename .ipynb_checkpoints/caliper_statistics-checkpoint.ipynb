# %%
import pandas as pd
import matplotlib.pyplot as mp

# %%
path_root = "./statistics/"

versions = ["cpu-dummy","redux","struct","coalesced"]
_INDEX_     = "NUM OF CORES"
_EXEC_TIME_ = "EXECUTION TIME"

# %%
# %ls ./statistics
# Out:
# coalesced2-aws.csv    cpu-dummy-aws.csv  redux-aws.csv    struct-aws.csv
# coalesced-aws.csv     cpu-local.csv      struct2-aws.csv  struct-opt-aws.csv
# cpu-basic-local2.csv  local/             struct3-aws.csv
# cpu-basic-local.csv   normal/            struct4-aws.csv

# %%
#Load csv data into a panda array
def load_statistic(path):
    path = path_root + path + "-aws.csv"
    print("Loading: " + path)
    x = pd.read_csv(path)
    #x = x.set_index(_INDEX_)
    return x

# %%
#Load all files with name contained in versions eg: ["redux","struct"]
def load_all_statistics(versions):
    res = {}
    for v in versions:
        res[v] = load_statistic(v)
    return res

# %%
#Merge all statistics in a single dataframe (mantain only execution times)
def merge_statistics(statistics):
    merged = load_statistic("redux")
    for s in statistics:
        merged[s] = statistics[s][_EXEC_TIME_]
    merged = merged[["NUM OF CORES"] + versions]
    return merged

# %%
#Can plot versions comparisons by passing an array of versions names eg ["redux","struct"]
def plot_versions(data,versions_to_plot):
    ax = data.plot(x=_INDEX_, y=versions_to_plot,kind="line", figsize=(10, 10))
    ax.set_ylabel("Execution Time[s]")
    ax.grid()
    # display plot
    mp.show()

# %%
def calculate_speedup(data,versions,reference_version="cpu-dummy"):
    df = pd.DataFrame(data)
    for v in versions:
        df["Speedup-"+v] = df[reference_version] / df[v]
        
    df = df.drop(["Speedup-"+reference_version],axis=1)
    return df

# %%
statistics = load_all_statistics(versions)
merged = merge_statistics(statistics)
speedups = calculate_speedup(merged,versions,"cpu-dummy")
# Out:
# Loading: ./statistics/cpu-dummy-aws.csv
# Loading: ./statistics/redux-aws.csv
# Loading: ./statistics/struct-aws.csv
# Loading: ./statistics/coalesced-aws.csv
# Loading: ./statistics/redux-aws.csv

# %%
merged
# Out:
#     NUM OF CORES    cpu-dummy        redux       struct   coalesced  \
# 0             16     1.607047     0.425617     0.466114    0.319937
# 1             25     3.889239     0.463464     0.524589    0.335340
# 2             36     7.573095     0.667788     0.665717    0.386682
# 3             49    14.063768     1.018746     0.976122    0.474588
# 4             64    23.487239     1.670904     1.446056    0.598059
# 5             81    37.771901     2.595702     2.136893    0.788512
# 6            100    56.842011     3.870425     3.029770    1.052209
# 7            121    83.592402     5.647244     4.295276    1.421808
# 8            144   117.360463     7.838579     5.923920    1.899554
# 9            169   162.270304    10.899327     8.053699    2.483355
# 10           196   216.861179    14.509186    10.618248    3.232865
# 11           225   287.129152    19.134069    13.966010    4.147140
# 12           256   369.241957    23.413404    17.877591    5.276269
# 13           289   471.141826    31.510934    22.692267    6.652472
# 14           324   590.041765    40.250295    28.459759    8.286774
# 15           361   734.799723    50.596748    35.279267   10.253651
# 16           400   899.338246    62.356657    43.114273   12.526668
# 17           484  1321.184794    91.115645    62.982127   18.308042
# 18           576  1874.843028   131.412301    89.250567   25.906951
# 19           676  2591.428865   179.443405   123.097167   35.709066
# 20           900  3462.441234   322.801138   227.631208   63.576854
# 21          1024  4550.033506   395.466795   327.042412   82.399343
# 22          1225  5912.760227   603.150023   565.595047  118.141697
# 23          1369  7511.204225   722.927067   796.564980  147.652370
# 24          1444  9442.525863  1036.159953   939.866054  163.145768
# 25          1600          NaN  1044.995413  1312.789202  201.864251
# 26          1764          NaN  1266.932813          NaN  245.588306
# 27          1849          NaN  1395.668813          NaN  295.295199
#
#     Speedup-cpu-dummy  Speedup-redux  Speedup-struct  Speedup-coalesced
# 0                 1.0       3.775805        3.447755           5.023010
# 1                 1.0       8.391674        7.413878          11.597897
# 2                 1.0      11.340567       11.375849          19.584824
# 3                 1.0      13.804978       14.407799          29.633641
# 4                 1.0      14.056604       16.242276          39.272433
# 5                 1.0      14.551710       17.676084          47.902761
# 6                 1.0      14.686245       18.761164          54.021603
# 7                 1.0      14.802336       19.461474          58.793041
# 8                 1.0      14.972161       19.811285          61.783167
# 9                 1.0      14.888103       20.148543          65.343175
# 10                1.0      14.946474       20.423443          67.080182
# 11                1.0      15.006173       20.559140          69.235461
# 12                1.0      15.770537       20.653899          69.981640
# 13                1.0      14.951694       20.762219          70.822068
# 14                1.0      14.659315       20.732493          71.202829
# 15                1.0      14.522667       20.828089          71.662253
# 16                1.0      14.422490       20.859409          71.793893
# 17                1.0      14.500087       20.977138          72.164177
# 18                1.0      14.266876       21.006511          72.368340
# 19                1.0      14.441483       21.051897          72.570615
# 20                1.0      10.726236       15.210749          54.460720
# 21                1.0      11.505475       13.912671          55.219294
# 22                1.0       9.803134       10.454052          50.048039
# 23                1.0      10.389989        9.429493          50.870868
# 24                1.0       9.113000       10.046672          57.877847
# 25                NaN            NaN             NaN                NaN
# 26                NaN            NaN             NaN                NaN
# 27                NaN            NaN             NaN                NaN

# %%
plot_versions(merged,versions) #Can plot versions comparisons by passing an array of versions names eg ["redux","struct"]

# %%
speedups
# Out:
#     NUM OF CORES    cpu-dummy        redux       struct   coalesced  \
# 0             16     1.607047     0.425617     0.466114    0.319937
# 1             25     3.889239     0.463464     0.524589    0.335340
# 2             36     7.573095     0.667788     0.665717    0.386682
# 3             49    14.063768     1.018746     0.976122    0.474588
# 4             64    23.487239     1.670904     1.446056    0.598059
# 5             81    37.771901     2.595702     2.136893    0.788512
# 6            100    56.842011     3.870425     3.029770    1.052209
# 7            121    83.592402     5.647244     4.295276    1.421808
# 8            144   117.360463     7.838579     5.923920    1.899554
# 9            169   162.270304    10.899327     8.053699    2.483355
# 10           196   216.861179    14.509186    10.618248    3.232865
# 11           225   287.129152    19.134069    13.966010    4.147140
# 12           256   369.241957    23.413404    17.877591    5.276269
# 13           289   471.141826    31.510934    22.692267    6.652472
# 14           324   590.041765    40.250295    28.459759    8.286774
# 15           361   734.799723    50.596748    35.279267   10.253651
# 16           400   899.338246    62.356657    43.114273   12.526668
# 17           484  1321.184794    91.115645    62.982127   18.308042
# 18           576  1874.843028   131.412301    89.250567   25.906951
# 19           676  2591.428865   179.443405   123.097167   35.709066
# 20           900  3462.441234   322.801138   227.631208   63.576854
# 21          1024  4550.033506   395.466795   327.042412   82.399343
# 22          1225  5912.760227   603.150023   565.595047  118.141697
# 23          1369  7511.204225   722.927067   796.564980  147.652370
# 24          1444  9442.525863  1036.159953   939.866054  163.145768
# 25          1600          NaN  1044.995413  1312.789202  201.864251
# 26          1764          NaN  1266.932813          NaN  245.588306
# 27          1849          NaN  1395.668813          NaN  295.295199
#
#     Speedup-redux  Speedup-struct  Speedup-coalesced
# 0        3.775805        3.447755           5.023010
# 1        8.391674        7.413878          11.597897
# 2       11.340567       11.375849          19.584824
# 3       13.804978       14.407799          29.633641
# 4       14.056604       16.242276          39.272433
# 5       14.551710       17.676084          47.902761
# 6       14.686245       18.761164          54.021603
# 7       14.802336       19.461474          58.793041
# 8       14.972161       19.811285          61.783167
# 9       14.888103       20.148543          65.343175
# 10      14.946474       20.423443          67.080182
# 11      15.006173       20.559140          69.235461
# 12      15.770537       20.653899          69.981640
# 13      14.951694       20.762219          70.822068
# 14      14.659315       20.732493          71.202829
# 15      14.522667       20.828089          71.662253
# 16      14.422490       20.859409          71.793893
# 17      14.500087       20.977138          72.164177
# 18      14.266876       21.006511          72.368340
# 19      14.441483       21.051897          72.570615
# 20      10.726236       15.210749          54.460720
# 21      11.505475       13.912671          55.219294
# 22       9.803134       10.454052          50.048039
# 23      10.389989        9.429493          50.870868
# 24       9.113000       10.046672          57.877847
# 25            NaN             NaN                NaN
# 26            NaN             NaN                NaN
# 27            NaN             NaN                NaN
