# %% [markdown]
# # Statistics about Caliper framework

# %% [markdown]
# ### Parameters to run script

# %%
statistics_file = './statistics/cpu_times.csv' #Too long names dosnt work on subprocess (dont know why)

script_name = './run-benchmark.sh'
script_args = " >> " + statistics_file
run_command = script_name
run_command
# Out:
# './run-benchmark.sh'

# %% [markdown]
#  ### Run the script to generate all the execution times statistics:

# %%
#UNCOMMENT THIS LINE TO REGENERATE THE .csv (WARNING!!! do backup of the csv!!!!)
import subprocess
#subprocess.call(run_command, shell=True)

# %% [markdown]
# ### Load the csv file generated by the script into a pandas dataframe

# %%
import pandas as pd

# %% [markdown]
# ### Chart comparisons:

# %%
statistic_fixed_test = './statistics/cpu_times_fixed_num_text.csv'
statistic_confidence = './statistics/cpu_times_confidence.csv'

# %%
fixed_test = pd.read_csv(statistic_fixed_test)
fixed_test = pd.DataFrame(fixed_test)
fixed_test_indexed = fixed_test.set_index("NUM_OF_CORES")
fixed_test_indexed
# Out:
#               ROWS  COLS  MIN_CORE  WORKLOAD  NUM_OF_TEST  CONFIDENCE  \
# NUM_OF_CORES
# 16               4     4         6    0.3750       100000   94.167054
# 25               5     5         6    0.2400       100000  120.175587
# 36               6     6         6    0.1666       100000  134.570839
# 49               7     7         6    0.1224       100000  142.309579
# 100             10    10         6    0.0600       100000  145.945951
# 121             11    11         6    0.0495       100000  145.272420
# 225             15    15         6    0.0266       100000  139.194318
# 400             20    20         6    0.0150       100000  131.715360
# 484             22    22         6    0.0123       100000  129.279416
#
#               EXECUTION TIME   MTTF[Hours]  MTTF[Years]
# NUM_OF_CORES
# 16                  1.782641  1.909274e+05    21.795362
# 25                  4.632125  3.323599e+05    37.940631
# 36                  9.780148  4.683426e+05    53.463771
# 49                 18.175694  5.903332e+05    67.389633
# 100                76.582042  8.732012e+05    99.680504
# 121               112.032064  9.460520e+05   107.996799
# 225               388.235419  1.165783e+06   133.080214
# 400              1221.876689  1.346286e+06   153.685621
# 484              1816.729992  1.404194e+06   160.296138

# %%
fixed_test_indexed["EXECUTION TIME"].plot()

plt.xlabel("Number of cores")
plt.ylabel("Execution time")
plt.show()

# %%
conficende_test = pd.read_csv(statistic_confidence)
conficende_test = pd.DataFrame(conficende_test)
conficende_test = conficende_test.set_index("NUM_OF_CORES")
conficende_test
# Out:
#               ROWS  COLS  MIN_CORE  WORKLOAD  NUM_OF_TEST  CONFIDENCE  \
# NUM_OF_CORES
# 16               4     4         6    0.3750         5574    4.780031
# 25               5     5         6    0.2400         3115    8.324971
# 36               6     6         6    0.1666         1909   11.735792
# 49               7     7         6    0.1224         1410   14.792091
# 100             10    10         6    0.0600          855   21.843703
# 121             11    11         6    0.0495          784   23.656991
# 225             15    15         6    0.0266          679   29.064776
# 256             16    16         6    0.0234          638   30.167206
# 289             17    17         6    0.0207          615   31.113007
# 324             18    18         6    0.0185          610   32.054961
# 361             19    19         6    0.0166          606   32.877345
# 400             20    20         6    0.0150          596   33.631033
# 484             22    22         6    0.0123          573   35.030791
# 625             25    25         6    0.0096          561   36.804672
# 900             30    30         6    0.0066          555   39.259195
# 1225            35    35         6    0.0048          536   41.264433
# 1600            40    40         6    0.0037          529   42.779236
# 1764            42    42         6    0.0034          529   43.169035
#
#               EXECUTION TIME   MTTF[Hours]  MTTF[Years]
# NUM_OF_CORES
# 16                  0.189874  1.912618e+05    21.833536
# 25                  0.140515  3.331141e+05    38.026727
# 36                  0.182547  4.697647e+05    53.626110
# 49                  0.256692  5.923058e+05    67.614823
# 100                 0.660904  8.749952e+05    99.885297
# 121                 0.903922  9.479197e+05   108.210007
# 225                 2.688074  1.164751e+06   132.962495
# 256                 3.209897  1.210015e+06   138.129525
# 289                 3.923963  1.246634e+06   142.309779
# 324                 4.902967  1.284971e+06   146.686159
# 361                 6.036482  1.318344e+06   150.495883
# 400                 7.301562  1.349023e+06   153.998075
# 484                10.362454  1.404758e+06   160.360490
# 625                16.855743  1.475122e+06   168.392908
# 900                34.616167  1.573939e+06   179.673406
# 1225               62.336976  1.654368e+06   188.854799
# 1600              105.098655  1.715187e+06   195.797633
# 1764              127.994615  1.732250e+06   197.745490

# %%
conficende_test["EXECUTION TIME"].plot()

plt.xlabel("Number of cores")
plt.ylabel("Execution time")
plt.show()

# %%
fixed_test_indexed["MTTF[Years]"].plot()

plt.xlabel("Number of cores")
plt.ylabel("MTTF[Years]")
plt.show()

# %%
gpu_test_file = "./statistics/gpu-redux-aws.csv"
gpu_test = pd.read_csv(gpu_test_file)
gpu_test = pd.DataFrame(gpu_test)
gpu_test_indexed = gpu_test.set_index("NUM_OF_CORES")
gpu_test_indexed
# Out:
#               ROWS  COLS  MIN_CORE  WORKLOAD  NUM_OF_TEST  CONFIDENCE  \
# NUM_OF_CORES
# 16               4     4         6    0.3750       100000         NaN
# 25               5     5         6    0.2400       100000         NaN
# 36               6     6         6    0.1666       100000         NaN
# 49               7     7         6    0.1224       100000         NaN
# 100             10    10         6    0.0600       100000         NaN
# 121             11    11         6    0.0495       100000         NaN
# 225             15    15         6    0.0266       100000         NaN
# 256             16    16         6    0.0234       100000         NaN
# 289             17    17         6    0.0207       100000         NaN
# 324             18    18         6    0.0185       100000         NaN
# 361             19    19         6    0.0166       100000         NaN
# 400             20    20         6    0.0150       100000         NaN
#
#               EXECUTION TIME   MTTF[Hours]  MTTF[Years]
# NUM_OF_CORES
# 16                  0.365804  2.213769e+05    25.271336
# 25                  0.556265  3.756519e+05    42.882632
# 36                  1.005216  5.240609e+05    59.824306
# 49                  1.853001  6.589295e+05    75.220263
# 100                 7.807149  9.761117e+05   111.428276
# 121                11.465855  1.058974e+06   120.887399
# 225                40.095596  1.311729e+06   149.740764
# 256                49.587821  1.360678e+06   155.328531
# 289                65.872270  1.406293e+06   160.535688
# 324                84.297378  1.447518e+06   165.241730
# 361               104.925672  1.486096e+06   169.645697
# 400               129.260226  1.521525e+06   173.690038

# %%
gpu_test_indexed["EXECUTION TIME"].plot()

plt.xlabel("Number of cores")
plt.ylabel("Execution time")
plt.show()

# %%
# Naming the x-axis, y-axis and the whole graph
gpu_test.reset_index(inplace = True)
fixed_test.reset_index(inplace = True)

plt.xlabel("Num Of Cores")
plt.ylabel("Execution Time")

ax = plt.gca()

gpu_test.plot(kind='line', x='NUM_OF_CORES',y='EXECUTION TIME',color='green',ax=ax)
fixed_test.plot(kind='line',x='NUM_OF_CORES',y='EXECUTION TIME', color='red', ax=ax)

plt.title("GPU vs CPU")
ax.legend(["GPU-redux", "CPU"]);
plt.show()
